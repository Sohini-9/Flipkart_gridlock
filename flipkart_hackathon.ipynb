# %%
# !python /content/drive/MyDrive/flipkart/m1_data_ingestion.py
# Out:
# [M1] Loaded raw dataset: 8173 rows, 46 columns
# [M1] Parsed 6 timestamp columns
# [M1] Dropped 149 invalid rows (8173 -> 8024)
# [M1] Valid (plausible, in-bbox) stretch values: 606 / 8024 rows (7.6%)
# [M1] Top 20 corridors by incident count:
#       Non-corridor: 3051 incidents
#       Mysore Road: 728 incidents
#       Bellary Road 1: 607 incidents
#       Tumkur Road: 458 incidents
#       Bellary Road 2: 379 incidents
#       Hosur Road: 297 incidents
#       ORR North 1: 274 incidents
#       Old Madras Road: 257 incidents
#       Magadi Road: 243 incidents
#       ORR East 1: 242 incidents
#       ORR North 2: 235 incidents
#       Bannerghata Road: 208 incidents
#       ORR East 2: 183 incidents
#       West of Chord Road: 172 incidents
#       ORR West 1: 166 incidents
#       CBD 2: 98 incidents
#       IRR(Thanisandra road): 95 incidents
#       Hennur Main Road: 94 incidents
#       Varthur Road: 75 incidents
#       Old Airport Road: 74 incidents
#
# [M1] Saved clean dataset -> /content/drive/MyDrive/flipkart/clean_incidents.csv
# [M1] Final shape: (8024, 22)
#
# [M1] Sample of cleaned data:
#            id event_type        event_cause  requires_road_closure priority    status      corridor  police_station            zone   latitude  longitude             junction                   start_datetime  hour day_of_week  dow_num  month  is_weekend  was_escalated  has_valid_stretch  stretch_km       veh_type
# 0  FKID000000  unplanned  vehicle_breakdown                  False     HIGH    closed   Tumkur Road          Peenya             NaN  13.040004  77.518099                  NaN 2024-03-07 17:01:48.111000+00:00    17    Thursday        3      3       False           True              False         NaN            lcv
# 1  FKID000001  unplanned  vehicle_breakdown                  False     HIGH  resolved    ORR East 1      HSR Layout             NaN  12.921876  77.645158                  NaN 2024-01-30 04:07:24.173000+00:00     4     Tuesday        1      1       False           True              False         NaN  heavy_vehicle
# 2  FKID000002  unplanned             others                  False      LOW    closed  Non-corridor   Wilson Garden  Central Zone 2  12.955622  77.585708      UrvashiJunction 2023-11-11 06:18:03.343000+00:00     6    Saturday        5     11        True           True              False         NaN            NaN
# 3  FKID000003  unplanned          tree_fall                   True      LOW    closed  Non-corridor  Sadashivanagar             NaN  13.006147  77.579435                  NaN 2024-03-07 17:56:55.061000+00:00    17    Thursday        3      3       False           True               True    0.013633            NaN
# 4  FKID000004  unplanned  vehicle_breakdown                  False      LOW    closed  Non-corridor   Wilson Garden             NaN  12.953980  77.585233  LalbaghMainGateJunc 2024-01-30 04:56:32.348000+00:00     4     Tuesday        1      1       False           True              False         NaN    private_bus

# %%
# !python /content/drive/MyDrive/flipkart/m2_feature_engineering.py
# Out:
# [M2] Loaded clean dataset: 8024 rows
# [M2] Training corridor models on 4973 labeled rows (21 unique corridors)
# [M2] RF corridor model training accuracy: 1.0000
# [M2] KNN corridor model training accuracy: 1.0000
# [M2] Saved corridor models (RF + KNN) -> /content/drive/MyDrive/flipkart/corridor_model.pkl
# [M2] Rows needing corridor prediction: 3051 / 8024
# [M2] Predictions accepted (RF/KNN agree AND combined conf >= 0.8): 1208 / 3051 (39.6%)
# [M2] RF/KNN agreement rate on predicted rows: 0.6899
# [M2] corridor_source breakdown:
# corridor_source
# original      4973
# unresolved    1843
# predicted     1208
# [M2] Built 5 CIS signal tables (using corridor_final for w_corridor):
#       w_cause      : 16 causes
#       w_planned    : 2 event types
#       w_escalation : 2 states
#       w_hour       : 24 hours
#       w_corridor   : 22 corridors
#
# [M2] signal_score stats:
# count    8024.000000
# mean        0.074153
# std         0.022927
# min         0.040552
# 25%         0.061062
# 50%         0.067451
# 75%         0.075546
# max         0.202147
# Name: signal_score, dtype: float64
#
# [M2] Validation - signal_score by closure outcome:
#       mean(closure=True)  = 0.1000
#       mean(closure=False) = 0.0721
#       correlation         = 0.3192
#
# [M2] Saved feature matrix -> /content/drive/MyDrive/flipkart/feature_matrix.csv
# [M2] Saved locked corridor reconstruction -> /content/drive/MyDrive/flipkart/corridor_reconstruction.csv
# [M2] Saved CIS signal tables -> /content/drive/MyDrive/flipkart/cis_signal_tables.json
# [M2] Feature matrix shape: (8024, 20)
# [M2] Saved LOCKED category encoding maps -> /content/drive/MyDrive/flipkart/category_encoding_maps.json
#       event_cause       : 16 categories
#       corridor_final    : 22 categories
#       police_station    : 54 categories
# [M2] Trained police_station nearest-neighbor lookup on 8024 points (54 unique stations) -> /content/drive/MyDrive/flipkart/police_station_nn.pkl
#
# [M2] Sample of feature matrix:
#            id  event_cause_code  corridor_final_code  police_station_code  event_type_planned  priority_high  was_escalated_int  is_weekend_int  hour  dow_num  month  signal_score   latitude  longitude  corridor_final        event_cause  corridor_confidence  corridor_agreement corridor_source  requires_road_closure
# 0  FKID000000                 0                    0                    0                   0              1                  1               0    17        3      3      0.079881  13.040004  77.518099     Tumkur Road  vehicle_breakdown             1.000000                   1        original                  False
# 1  FKID000001                 0                    1                    1                   0              1                  1               0     4        1      1      0.060574  12.921876  77.645158      ORR East 1  vehicle_breakdown             1.000000                   1        original                  False
# 2  FKID000002                 1                    2                    2                   0              0                  1               1     6        5     11      0.087478  12.955622  77.585708     Mysore Road             others             0.886667                   1       predicted                  False
# 3  FKID000003                 2                    3                    3                   0              0                  1               0    17        3      3      0.154614  13.006147  77.579435  Bellary Road 1          tree_fall             0.845000                   1       predicted                   True
# 4  FKID000004                 0                    2                    2                   0              0                  1               0     4        1      1      0.068456  12.953980  77.585233     Mysore Road  vehicle_breakdown             0.850668                   1       predicted                  False

# %%
# !python /content/drive/MyDrive/flipkart/m3_tgcf_calibration.py
# Out:
# [M3] Loaded existing cache: 273 cached responses (already-paid-for calls will be skipped)
# [M3] Purged 0 stale fallback entries from cache (273 valid entries kept). Safe to re-run now.
# [M3] 21 real corridors for MapMyIndia calibration:
#       Mysore Road: 925 incidents
#       Bellary Road 1: 683 incidents
#       Tumkur Road: 560 incidents
#       Bellary Road 2: 423 incidents
#       ORR East 2: 405 incidents
#       Hosur Road: 361 incidents
#       Magadi Road: 343 incidents
#       ORR West 1: 339 incidents
#       ORR North 1: 284 incidents
#       ORR North 2: 280 incidents
#       ORR East 1: 275 incidents
#       Old Madras Road: 273 incidents
#       Bannerghata Road: 225 incidents
#       West of Chord Road: 193 incidents
#       Hennur Main Road: 118 incidents
#       IRR(Thanisandra road): 113 incidents
#       CBD 2: 106 incidents
#       Airport New South Road: 97 incidents
#       Varthur Road: 77 incidents
#       Old Airport Road: 75 incidents
#       CBD 1: 26 incidents
# [M3] Real hour is 14:00 -> filling TIME_SLOT '14' for all corridors
# [M3] Loaded existing eta_baselines.json - merging into it, not overwriting
# [M3]   Mysore Road               slot 14 filled (eta_traffic=33.75 min, real hour=14:00)
# [M3]   Bellary Road 1            slot 14 filled (eta_traffic=12.0 min, real hour=14:00)
# [M3]   Tumkur Road               slot 14 filled (eta_traffic=30.69 min, real hour=14:00)
# [M3]   Bellary Road 2            slot 14 filled (eta_traffic=18.94 min, real hour=14:00)
# [M3]   ORR East 2                slot 14 filled (eta_traffic=15.07 min, real hour=14:00)
# [M3]   Hosur Road                slot 14 filled (eta_traffic=12.25 min, real hour=14:00)
# [M3]   Magadi Road               slot 14 filled (eta_traffic=28.45 min, real hour=14:00)
# [M3]   ORR West 1                slot 14 filled (eta_traffic=10.63 min, real hour=14:00)
# [M3]   ORR North 1               slot 14 filled (eta_traffic=5.21 min, real hour=14:00)
# [M3]   ORR North 2               slot 14 filled (eta_traffic=23.7 min, real hour=14:00)
# [M3]   ORR East 1                slot 14 filled (eta_traffic=15.22 min, real hour=14:00)
# [M3]   Old Madras Road           slot 14 filled (eta_traffic=20.0 min, real hour=14:00)
# [M3]   Bannerghata Road          slot 14 filled (eta_traffic=30.97 min, real hour=14:00)
# [M3]   West of Chord Road        slot 14 filled (eta_traffic=14.51 min, real hour=14:00)
# [M3]   Hennur Main Road          slot 14 filled (eta_traffic=32.66 min, real hour=14:00)
# [M3]   IRR(Thanisandra road)     slot 14 filled (eta_traffic=8.51 min, real hour=14:00)
# [M3]   CBD 2                     slot 14 filled (eta_traffic=2.67 min, real hour=14:00)
# [M3]   Airport New South Road    slot 14 filled (eta_traffic=22.99 min, real hour=14:00)
# [M3]   Varthur Road              slot 14 filled (eta_traffic=21.46 min, real hour=14:00)
# [M3]   Old Airport Road          slot 14 filled (eta_traffic=11.58 min, real hour=14:00)
# [M3]   CBD 1                     slot 14 filled (eta_traffic=10.55 min, real hour=14:00)
#
# [M3] Saved (merged) -> /content/drive/MyDrive/flipkart/eta_baselines.json
# [M3] ALL 12 slots filled for all 21 corridors - calibration complete!

# %%
# !python /content/drive/MyDrive/flipkart/m4a_closure_classifier.py
# Out:
# ======================================================================
# [M4a] Road closure model - improved blend using M2 corridor_final
# ======================================================================
# [M4a] Loaded raw data: 8173 rows from /content/drive/MyDrive/flipkart/data.csv
# [M4a] Loaded M2 corridor model bundle -> /content/drive/MyDrive/flipkart/corridor_model.pkl
# [M4a] Dataset: 8173 rows | closure rate: 8.27%
# [M4a] Selected threshold: 0.230
# [M4a] Test precision=0.4702 recall=0.5259 f1=0.4965 roc_auc=0.8188
# [M4a] Saved closure bundle -> /content/drive/MyDrive/flipkart/closure_model_bundle.pkl
# [M4a] Saved metrics -> /content/drive/MyDrive/flipkart/closure_eval_metrics.json

# %%
# !python /content/drive/MyDrive/flipkart/m4b_congestion_scorer.py
# Out:
# [M4b] Loaded feature matrix: 8024 rows
# [M4b] Loaded ETA baselines for 21 corridors (excluding _meta)
# [M4b] Trained nearest-neighbor corridor lookup on 6181 labeled points
# [M4b] Assigned nearest-neighbor baseline corridor to 1843 Non-corridor rows
# [M4b] Nearest-neighbor distance stats (km): mean=1.317, median=0.751, max=20.439
# [M4b] WARNING: 335 rows have nearest-neighbor distance > 2km (weak match - baseline borrowed from a fairly distant corridor)
# [M4b] max_possible (95th percentile of raw_score): 13.6336
#
# [M4b] CIS distribution:
# count    8024.000000
# mean        1.605994
# std         2.760051
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.126090
# max        10.000000
# Name: CIS, dtype: float64
#
# [M4b] === CIS validation against real closure outcome ===
#       Mean CIS (closure=True)  : 1.965
#       Mean CIS (closure=False) : 1.577
#       Difference                : +0.387
#       (Honest framing: this is a sanity check, not proof of true severity -
#        no continuous severity ground truth exists in this dataset.)
#
# [M4b] === Directional sanity checks ===
#       construction (2.94) > vehicle_breakdown (1.59): True
#       peak hours (2.90) > night hours (0.16): True
#       closure=True (1.96) > closure=False (1.58): True
#       planned (2.92) > unplanned (1.54): True
#
# [M4b] Sanity checks passed: 4/4
#
# [M4b] === XGBoost CIS regressor evaluation (test set, n=1605) ===
#       MAE  : 0.4441  (on 0-10 scale)
#       RMSE : 0.9261
#       R2   : 0.8925
#
# [M4b] XGBoost feature importances:
#       hour                     : 0.4013
#       corridor_final_code      : 0.3116
#       priority_high            : 0.1013
#       police_station_code      : 0.0464
#       event_type_planned       : 0.0316
#       event_cause_code         : 0.0306
#       was_escalated_int        : 0.0235
#       month                    : 0.0204
#       dow_num                  : 0.0199
#       is_weekend_int           : 0.0134
#
# [M4b] Saved XGBoost model -> /content/drive/MyDrive/flipkart/scorer_model.pkl
#
# [M4b] Saved CIS scores + audit trail -> /content/drive/MyDrive/flipkart/cis_scores.csv
# [M4b] Saved evaluation metrics -> /content/drive/MyDrive/flipkart/scorer_eval_metrics.json
#
# [M4b] Sample CIS output:
#            id        event_cause  corridor_final            baseline_source       CIS
# 0  FKID000000  vehicle_breakdown     Tumkur Road               own_corridor  4.376745
# 1  FKID000001  vehicle_breakdown      ORR East 1               own_corridor  0.000000
# 2  FKID000002             others     Mysore Road               own_corridor  0.000000
# 3  FKID000003          tree_fall  Bellary Road 1               own_corridor  7.632276
# 4  FKID000004  vehicle_breakdown     Mysore Road               own_corridor  0.000000
# 5  FKID000005           accident  Bellary Road 2               own_corridor  0.000000
# 6  FKID000006  vehicle_breakdown     Mysore Road               own_corridor  0.000000
# 7  FKID000007             others    Non-corridor  nearest_neighbor_fallback  0.000000
# 8  FKID000009  vehicle_breakdown    Non-corridor  nearest_neighbor_fallback  0.000000
# 9  FKID000010      water_logging      ORR East 2               own_corridor  2.765812

# %%
# !python /content/drive/MyDrive/flipkart/m4c_incident_forecaster.py
# Out:
# [M4c] Loaded 8024 incidents with corridor_final + start_datetime
# [M4c] Date range: 2023-11-09 19:24:48.154000+00:00 -> 2024-04-08 17:11:42.780000+00:00
#
# [M4c] Forecasting 22 corridor series (including 'Non-corridor' as its own series, per locked decision)
# [M4c] Train period: start of data -> 2024-02-29
# [M4c] Test period : 2024-03-01 -> end of data
#
# [M4c] === Confidence assessment per corridor ===
# [M4c]   Airport New South Road    avg/wk=  4.22  zero_weeks= 4/23  nonzero_weeks=19  -> LOW_CONFIDENCE (avg_weekly=4.22 < 8.0)
# [M4c]   Bannerghata Road          avg/wk=  9.78  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   Bellary Road 1            avg/wk= 29.70  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   Bellary Road 2            avg/wk= 18.39  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   CBD 1                     avg/wk=  1.13  zero_weeks=12/23  nonzero_weeks=11  -> LOW_CONFIDENCE (avg_weekly=1.13 < 8.0; zero_week_fraction=0.52 > 0.25)
# [M4c]   CBD 2                     avg/wk=  4.61  zero_weeks= 0/23  nonzero_weeks=23  -> LOW_CONFIDENCE (avg_weekly=4.61 < 8.0)
# [M4c]   Hennur Main Road          avg/wk=  5.13  zero_weeks= 2/23  nonzero_weeks=21  -> LOW_CONFIDENCE (avg_weekly=5.13 < 8.0)
# [M4c]   Hosur Road                avg/wk= 15.70  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   IRR(Thanisandra road)     avg/wk=  4.91  zero_weeks= 1/23  nonzero_weeks=22  -> LOW_CONFIDENCE (avg_weekly=4.91 < 8.0)
# [M4c]   Magadi Road               avg/wk= 14.91  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   Mysore Road               avg/wk= 40.22  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   Non-corridor              avg/wk= 80.13  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   ORR East 1                avg/wk= 11.96  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   ORR East 2                avg/wk= 17.61  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   ORR North 1               avg/wk= 12.35  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   ORR North 2               avg/wk= 12.17  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   ORR West 1                avg/wk= 14.74  zero_weeks= 1/23  nonzero_weeks=22  -> OK
# [M4c]   Old Airport Road          avg/wk=  3.26  zero_weeks= 2/23  nonzero_weeks=21  -> LOW_CONFIDENCE (avg_weekly=3.26 < 8.0)
# [M4c]   Old Madras Road           avg/wk= 11.87  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   Tumkur Road               avg/wk= 24.35  zero_weeks= 0/23  nonzero_weeks=23  -> OK
# [M4c]   Varthur Road              avg/wk=  3.35  zero_weeks= 3/23  nonzero_weeks=20  -> LOW_CONFIDENCE (avg_weekly=3.35 < 8.0)
# [M4c]   West of Chord Road        avg/wk=  8.39  zero_weeks= 1/23  nonzero_weeks=22  -> OK
#
# [M4c] 7/22 corridors flagged LOW_CONFIDENCE (forecast anyway, per locked decision - flagged, not skipped)
#
# [M4c] === Per-corridor temporal evaluation (train: pre-Mar 2024, test: Mar-Apr 2024) ===
# 14:31:03 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:03 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Airport New South Road    MAE=  3.88  MAPE=  54.0% (on 4/6 nonzero test weeks)
# 14:31:04 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:04 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bannerghata Road          MAE=  6.34  MAPE=  30.8% (on 5/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bellary Road 1            MAE= 20.20  MAPE= 227.9% (on 6/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bellary Road 2            MAE=  6.23  MAPE= 319.5% (on 6/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   CBD 1                     MAE=  2.00  MAPE=  72.6% (on 3/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   CBD 2                     MAE=  3.55  MAPE= 172.2% (on 6/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Hennur Main Road          MAE=  5.33  MAPE= 150.8% (on 5/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Hosur Road                MAE=  7.51  MAPE=  60.9% (on 5/6 nonzero test weeks)
# 14:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:05 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   IRR(Thanisandra road)     MAE=  5.51  MAPE=  78.0% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Magadi Road               MAE=  7.27  MAPE= 127.2% (on 6/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Mysore Road               MAE= 25.33  MAPE=  37.0% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Non-corridor              MAE= 48.79  MAPE= 338.8% (on 6/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR East 1                MAE=  8.12  MAPE=  29.1% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR East 2                MAE=  9.59  MAPE= 207.2% (on 6/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR North 1               MAE=  8.28  MAPE= 214.5% (on 6/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR North 2               MAE=  7.54  MAPE=  28.7% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR West 1                MAE=  8.66  MAPE=  24.0% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Old Airport Road          MAE=  2.96  MAPE= 143.9% (on 5/6 nonzero test weeks)
# 14:31:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:06 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Old Madras Road           MAE=  7.39  MAPE= 296.8% (on 6/6 nonzero test weeks)
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Tumkur Road               MAE= 11.26  MAPE= 445.5% (on 6/6 nonzero test weeks)
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Varthur Road              MAE=  2.82  MAPE=  54.1% (on 5/6 nonzero test weeks)
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   West of Chord Road        MAE=  8.27  MAPE= 138.6% (on 6/6 nonzero test weeks)
#
# [M4c] Mean MAE across corridors with a valid split: 9.858
#
# [M4c] === Fitting deployment models (full data) + generating forecasts ===
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Airport New South Road    -> saved /content/drive/MyDrive/flipkart/prophet_models/Airport_New_South_Road.pkl
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bannerghata Road          -> saved /content/drive/MyDrive/flipkart/prophet_models/Bannerghata_Road.pkl
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bellary Road 1            -> saved /content/drive/MyDrive/flipkart/prophet_models/Bellary_Road_1.pkl
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Bellary Road 2            -> saved /content/drive/MyDrive/flipkart/prophet_models/Bellary_Road_2.pkl
# 14:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:07 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   CBD 1                     -> saved /content/drive/MyDrive/flipkart/prophet_models/CBD_1.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   CBD 2                     -> saved /content/drive/MyDrive/flipkart/prophet_models/CBD_2.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Hennur Main Road          -> saved /content/drive/MyDrive/flipkart/prophet_models/Hennur_Main_Road.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Hosur Road                -> saved /content/drive/MyDrive/flipkart/prophet_models/Hosur_Road.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   IRR(Thanisandra road)     -> saved /content/drive/MyDrive/flipkart/prophet_models/IRR_Thanisandra_road.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Magadi Road               -> saved /content/drive/MyDrive/flipkart/prophet_models/Magadi_Road.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Mysore Road               -> saved /content/drive/MyDrive/flipkart/prophet_models/Mysore_Road.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:08 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Non-corridor              -> saved /content/drive/MyDrive/flipkart/prophet_models/Non_corridor.pkl
# 14:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR East 1                -> saved /content/drive/MyDrive/flipkart/prophet_models/ORR_East_1.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR East 2                -> saved /content/drive/MyDrive/flipkart/prophet_models/ORR_East_2.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR North 1               -> saved /content/drive/MyDrive/flipkart/prophet_models/ORR_North_1.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR North 2               -> saved /content/drive/MyDrive/flipkart/prophet_models/ORR_North_2.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   ORR West 1                -> saved /content/drive/MyDrive/flipkart/prophet_models/ORR_West_1.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Old Airport Road          -> saved /content/drive/MyDrive/flipkart/prophet_models/Old_Airport_Road.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Old Madras Road           -> saved /content/drive/MyDrive/flipkart/prophet_models/Old_Madras_Road.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:09 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Tumkur Road               -> saved /content/drive/MyDrive/flipkart/prophet_models/Tumkur_Road.pkl
# 14:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:10 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   Varthur Road              -> saved /content/drive/MyDrive/flipkart/prophet_models/Varthur_Road.pkl
# 14:31:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:31:10 - cmdstanpy - INFO - Chain [1] done processing
# [M4c]   West of Chord Road        -> saved /content/drive/MyDrive/flipkart/prophet_models/West_of_Chord_Road.pkl
#
# [M4c] Saved forecast -> /content/drive/MyDrive/flipkart/forecast.json
# [M4c] Saved evaluation metrics -> /content/drive/MyDrive/flipkart/forecaster_eval_metrics.json
#
# [M4c] Sample forecast (first corridor):
# {
#   "Airport New South Road": {
#     "confidence": "LOW_CONFIDENCE",
#     "confidence_reasons": [
#       "avg_weekly=4.22 < 8.0"
#     ],
#     "avg_weekly_incidents_historical": 4.217391304347826,
#     "next_weeks_forecast": [
#       {
#         "week_start": "2024-04-15",
#         "predicted_incidents": 4.3,
#         "yhat_lower": 0.0,
#         "yhat_upper": 8.9
#       },
#       {
#         "week_start": "2024-04-22",
#         "predicted_incidents": 4.3,
#         "yhat_lower": 0.0,
#         "yhat_upper": 9.0
#       },
#       {
#         "week_start": "2024-04-29",
#         "predicted_incidents": 4.4,
#         "yhat_lower": 0.0,
#         "yhat_upper": 9.0
#       },
#       {
#         "week_start": "2024-05-06",
#         "predicted_incidents": 4.4,
#         "yhat_lower": 0.0,
#         "yhat_upper": 9.0
#       }
#     ],
#     "model_path": "/content/drive/MyDrive/flipkart/prophet_models/Airport_New_South_Road.pkl"
#   }
# }

# %%
# !python /content/drive/MyDrive/flipkart/m5_inference_engine.py
# Out:
# [M5] Loaded M4c forecast context.
# [M5] Loaded artifacts from /content/drive/MyDrive/flipkart/
# [M5] Closure model: blend(ExtraTrees_w6 x0.5 + RandomForest_w4 x0.5)
# [M5] CIS scorer model class: XGBRegressor
#
# ======================================================================
# [M5] DEMO EVENT 1
# ======================================================================
# {
#   "input": {
#     "latitude": 12.9716,
#     "longitude": 77.5573,
#     "event_cause": "vehicle_breakdown",
#     "event_type": "unplanned",
#     "priority": "LOW",
#     "timestamp": "2026-06-20T17:30:00+00:00",
#     "was_escalated": false,
#     "description": "lorry breakdown on left lane, slow traffic",
#     "address": "Mysore Road, Bengaluru"
#   },
#   "resolved_location": {
#     "corridor_final": "Non-corridor",
#     "corridor_confidence": 0.74,
#     "corridor_agreement": 0,
#     "corridor_source": "unresolved",
#     "rf_corridor_prediction": "Mysore Road",
#     "rf_corridor_confidence": 0.48,
#     "knn_corridor_prediction": "Magadi Road",
#     "knn_corridor_confidence": 1.0,
#     "police_station": "Magadi Road",
#     "police_station_nn_distance_km": 0.45525158518775516
#   },
#   "baseline_lookup": {
#     "baseline_corridor": "Magadi Road",
#     "baseline_source": "nearest_neighbor_fallback",
#     "nn_distance_km": 0.45525158518775516
#   },
#   "closure_prediction": {
#     "requires_road_closure_predicted": false,
#     "closure_probability": 0.1375,
#     "decision_threshold": 0.23,
#     "model": "blend(ExtraTrees_w6 x0.5 + RandomForest_w4 x0.5)",
#     "model_roc_auc": 0.8188,
#     "text_available": true,
#     "model_a_probability": 0.1333,
#     "model_b_structured_probability": 0.1417
#   },
#   "congestion_impact_score": {
#     "cis_formula_based": 5.357,
#     "cis_ml_based": 5.497,
#     "cis_ml_model_class": "XGBRegressor",
#     "baseline_delay_min": 7.86,
#     "signal_score": 0.0929,
#     "snapped_hour_used_for_baseline": 16
#   },
#   "corridor_forecast_context": {
#     "available": true,
#     "confidence": "OK",
#     "avg_weekly_incidents_historical": 80.1304347826087,
#     "next_week_forecast": {
#       "week_start": "2024-04-15",
#       "predicted_incidents": 92.6,
#       "yhat_lower": 46.6,
#       "yhat_upper": 138.3
#     }
#   }
# }
#
# ======================================================================
# [M5] DEMO EVENT 2
# ======================================================================
# {
#   "input": {
#     "latitude": 13.005,
#     "longitude": 77.57,
#     "event_cause": "vip_movement",
#     "event_type": "planned",
#     "priority": "HIGH",
#     "timestamp": "2026-06-20T09:00:00+00:00",
#     "was_escalated": false,
#     "description": "traffic diverted and road closed for convoy movement",
#     "address": "Bellary Road, Bengaluru"
#   },
#   "resolved_location": {
#     "corridor_final": "Non-corridor",
#     "corridor_confidence": 0.7066666666666667,
#     "corridor_agreement": 0,
#     "corridor_source": "unresolved",
#     "rf_corridor_prediction": "Bellary Road 1",
#     "rf_corridor_confidence": 0.4133,
#     "knn_corridor_prediction": "Tumkur Road",
#     "knn_corridor_confidence": 1.0,
#     "police_station": "Malleshwaram",
#     "police_station_nn_distance_km": 0.10070923256805715
#   },
#   "baseline_lookup": {
#     "baseline_corridor": "Bellary Road 1",
#     "baseline_source": "nearest_neighbor_fallback",
#     "nn_distance_km": 0.7305391031115821
#   },
#   "closure_prediction": {
#     "requires_road_closure_predicted": true,
#     "closure_probability": 0.346,
#     "decision_threshold": 0.23,
#     "model": "blend(ExtraTrees_w6 x0.5 + RandomForest_w4 x0.5)",
#     "model_roc_auc": 0.8188,
#     "text_available": true,
#     "model_a_probability": 0.33,
#     "model_b_structured_probability": 0.362
#   },
#   "congestion_impact_score": {
#     "cis_formula_based": 0.0,
#     "cis_ml_based": 0.0,
#     "cis_ml_model_class": "XGBRegressor",
#     "baseline_delay_min": 0.0,
#     "signal_score": 0.1008,
#     "snapped_hour_used_for_baseline": 8
#   },
#   "corridor_forecast_context": {
#     "available": true,
#     "confidence": "OK",
#     "avg_weekly_incidents_historical": 80.1304347826087,
#     "next_week_forecast": {
#       "week_start": "2024-04-15",
#       "predicted_incidents": 92.6,
#       "yhat_lower": 46.6,
#       "yhat_upper": 138.3
#     }
#   }
# }

# %%
# !python /content/drive/MyDrive/flipkart/m6_resource_rule_engine.py
# Out:
# [M5] Loaded M4c forecast context.
# [M5] Loaded artifacts from /content/drive/MyDrive/flipkart/
# [M5] Closure model: blend(ExtraTrees_w6 x0.5 + RandomForest_w4 x0.5)
# [M5] CIS scorer model class: XGBRegressor
#
# ======================================================================
# [M6] DEMO EVENT 1
# ======================================================================
# {
#   "cis_used": 2.289,
#   "cis_used_source": "cis_ml_based",
#   "cis_based_tier": "LOW",
#   "closure_predicted": false,
#   "closure_probability": 0.1874,
#   "closure_override_applied": false,
#   "final_tier": "LOW",
#   "officer_count": 1,
#   "barricade_count": 0,
#   "diversion_priority": "NONE",
#   "rationale": "Minor incident, bottom quartile of the ML-predicted CIS distribution, historical closure rate in this band is ~5.3%. Single officer for traffic guidance/logging; no physical barricading by default.",
#   "cis_disagreement_check": {
#     "checked": true,
#     "cis_formula_based": 2.544,
#     "cis_ml_based": 2.289,
#     "absolute_gap": 0.255,
#     "flagged_as_high_disagreement": false
#   },
#   "tier_thresholds_used": [
#     {
#       "name": "LOW",
#       "min_cis": 0.0,
#       "max_cis": 3.4
#     },
#     {
#       "name": "MODERATE",
#       "min_cis": 3.4,
#       "max_cis": 4.7
#     },
#     {
#       "name": "ELEVATED",
#       "min_cis": 4.7,
#       "max_cis": 7.3
#     },
#     {
#       "name": "HIGH",
#       "min_cis": 7.3,
#       "max_cis": 10.001
#     }
#   ],
#   "resource_counts_are_reasoned_defaults_not_learned": true,
#   "generated_at": "2026-06-21T14:32:55.950114+00:00"
# }
#
# ======================================================================
# [M6] DEMO EVENT 2
# ======================================================================
# {
#   "cis_used": 0.0,
#   "cis_used_source": "cis_ml_based",
#   "cis_based_tier": "LOW",
#   "closure_predicted": true,
#   "closure_probability": 0.4424,
#   "closure_override_applied": true,
#   "final_tier": "ELEVATED",
#   "officer_count": 3,
#   "barricade_count": 4,
#   "diversion_priority": "ADVISORY",
#   "rationale": "Third quartile. Closure rate climbs to ~7.0% here, the first sign of the upward trend that peaks in the top quartile - ADVISORY diversion means a route is computed and ready but not pushed to drivers/dashboard by default, only on operator confirmation.",
#   "cis_disagreement_check": {
#     "checked": true,
#     "cis_formula_based": 0.0,
#     "cis_ml_based": 0.0,
#     "absolute_gap": 0.0,
#     "flagged_as_high_disagreement": false
#   },
#   "tier_thresholds_used": [
#     {
#       "name": "LOW",
#       "min_cis": 0.0,
#       "max_cis": 3.4
#     },
#     {
#       "name": "MODERATE",
#       "min_cis": 3.4,
#       "max_cis": 4.7
#     },
#     {
#       "name": "ELEVATED",
#       "min_cis": 4.7,
#       "max_cis": 7.3
#     },
#     {
#       "name": "HIGH",
#       "min_cis": 7.3,
#       "max_cis": 10.001
#     }
#   ],
#   "resource_counts_are_reasoned_defaults_not_learned": true,
#   "generated_at": "2026-06-21T14:32:56.347264+00:00"
# }
#
# ======================================================================
# [M6] DEMO EVENT 3
# ======================================================================
# [M5] WARNING: nearest labeled corridor 'Varthur Road' is 2.38km away for this Non-corridor event.
# {
#   "cis_used": 1.405,
#   "cis_used_source": "cis_ml_based",
#   "cis_based_tier": "LOW",
#   "closure_predicted": false,
#   "closure_probability": 0.1785,
#   "closure_override_applied": false,
#   "final_tier": "LOW",
#   "officer_count": 1,
#   "barricade_count": 0,
#   "diversion_priority": "NONE",
#   "rationale": "Minor incident, bottom quartile of the ML-predicted CIS distribution, historical closure rate in this band is ~5.3%. Single officer for traffic guidance/logging; no physical barricading by default.",
#   "cis_disagreement_check": {
#     "checked": true,
#     "cis_formula_based": 1.73,
#     "cis_ml_based": 1.405,
#     "absolute_gap": 0.325,
#     "flagged_as_high_disagreement": false
#   },
#   "tier_thresholds_used": [
#     {
#       "name": "LOW",
#       "min_cis": 0.0,
#       "max_cis": 3.4
#     },
#     {
#       "name": "MODERATE",
#       "min_cis": 3.4,
#       "max_cis": 4.7
#     },
#     {
#       "name": "ELEVATED",
#       "min_cis": 4.7,
#       "max_cis": 7.3
#     },
#     {
#       "name": "HIGH",
#       "min_cis": 7.3,
#       "max_cis": 10.001
#     }
#   ],
#   "resource_counts_are_reasoned_defaults_not_learned": true,
#   "generated_at": "2026-06-21T14:32:56.757691+00:00"
# }
#
# [M6] Saved 3 demo resource plans -> /content/drive/MyDrive/flipkart/resource_plan.json
